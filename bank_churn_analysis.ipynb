# %% [markdown]
# #Data Exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/BankChurnAnalysis/BankChurners.csv")

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 24 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
df.nunique(axis=0)
# Out:
# CLIENTNUM                                                                                                                             10127
# Attrition_Flag                                                                                                                            2
# Customer_Age                                                                                                                             45
# Gender                                                                                                                                    2
# Dependent_count                                                                                                                           6
# Education_Level                                                                                                                           7
# Marital_Status                                                                                                                            4
# ...

# %%
from pandas.core.dtypes.missing import isna
df["Attrition_Flag"].value_counts(isna==True)
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
df["flag"] = 1* (df["Attrition_Flag"]=="Existing Customer")
df["flag"].value_counts()
# Out:
# 1    8500
# 0    1627
# Name: flag, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %%
type(df["Customer_Age"][0])
# Out:
# numpy.int64

# %% [markdown]
# ### Data Exploration for categorical data

# %%
df_cat = df[['Attrition_Flag','Gender','Education_Level','Marital_Status','Income_Category','Card_Category']]

# %%
sns.set(rc={'figure.figsize':(12,8)})

# %%
ax0 = sns.countplot(x=df["Attrition_Flag"],data=df)

# %%
ax1 = sns.countplot(x=df["Gender"],hue="Attrition_Flag",order = df['Gender'].value_counts().index,data=df)

# %%
ax2 = sns.countplot(x=df["Education_Level"],hue="Attrition_Flag",order = df['Education_Level'].value_counts().index, data=df)

# %%
ax3 = sns.countplot(x=df["Income_Category"],hue="Attrition_Flag",order = df['Income_Category'].value_counts().index,data=df)

# %%
ax4 = sns.countplot(x=df["Marital_Status"],hue="Attrition_Flag",order = df['Marital_Status'].value_counts().index,data=df)

# %%
ax5 = sns.countplot(x=df["Card_Category"],hue="Attrition_Flag",order = df['Card_Category'].value_counts().index,data=df)

# %%
ax6 = sns.countplot(x=df["Income_Category"],hue="Attrition_Flag",order = df['Income_Category'].value_counts().index,data=df)

# %% [markdown]
# ### Data Exploration for numerical data

# %%
df_num = df[['Customer_Age','Dependent_count','Months_on_book','Total_Relationship_Count','Contacts_Count_12_mon','Credit_Limit']]

# %%
ax7 = sns.boxplot(x=df["Customer_Age"],data=df)

# %%
ax8 = sns.boxplot(x=df["Dependent_count"],data=df)

# %%
ax9 = sns.boxplot(x=df["Months_on_book"],data=df)

# %%
ax10 = sns.boxplot(x=df["Total_Relationship_Count"],data=df)

# %%
ax10 = sns.boxplot(x=df["Contacts_Count_12_mon"],data=df)

# %%
ax11 = sns.boxplot(x=df["Credit_Limit"],data=df)

# %%
print(df_num.corr())
sns.heatmap(df_num.corr())
# Out:
#                           Customer_Age  Dependent_count  Months_on_book  \
# Customer_Age                  1.000000        -0.122254        0.788912
# Dependent_count              -0.122254         1.000000       -0.103062
# Months_on_book                0.788912        -0.103062        1.000000
# Total_Relationship_Count     -0.010931        -0.039076       -0.009203
# Contacts_Count_12_mon        -0.018452        -0.040505       -0.010774
# Credit_Limit                  0.002476         0.068065        0.007507
#
#                           Total_Relationship_Count  Contacts_Count_12_mon  \
# Customer_Age                             -0.010931              -0.018452
# Dependent_count                          -0.039076              -0.040505
# Months_on_book                           -0.009203              -0.010774
# Total_Relationship_Count                  1.000000               0.055203
# Contacts_Count_12_mon                     0.055203               1.000000
# ...

# %%
pd.pivot_table(df, index = 'Attrition_Flag', values = ['Customer_Age','Dependent_count','Months_on_book','Total_Relationship_Count','Contacts_Count_12_mon','Credit_Limit'])
# Out:
#                    Contacts_Count_12_mon  Credit_Limit  Customer_Age  \
# Attrition_Flag
# Attrited Customer               2.972342   8136.039459     46.659496
# Existing Customer               2.356353   8726.877518     46.262118
#
#                    Dependent_count  Months_on_book  Total_Relationship_Count
# Attrition_Flag
# Attrited Customer         2.402581       36.178242                  3.279656
# Existing Customer         2.335412       35.880588                  3.914588

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# #Feature Enginearing

# %% [markdown]
# # Training the model

# %% [markdown]
# #Evaluating the model
